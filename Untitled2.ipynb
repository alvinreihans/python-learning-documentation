# %%
print("          Selamat Datang            \n"
    "====================================\n"
    "Silahkan pilih menu yang diingginkan\n"
    "1 = Untuk menampilkan gambar        \n"
    "2 = Untuk menampilkan Histogram     \n")

pilihan = int(input("Masukkan Pilihan Anda = "))
if pilihan == 1:
    import matplotlib, cv2
    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.image as mping
    print("Masukkan Pilihan Warna yang ingin Anda masukkan\n"
         "===============================================\n"
         "1 untuk warna Gray\n"
         "2 untuk warna RGB\n")
    warna = int(input("Masukkan Pilihan = "))
    if warna == 1:
        img = cv2.imread(r'contoh.jpg')
        im = mping.imread(r'contoh.jpg')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        plt.imshow(img)
    elif warna == 2:
        img = cv2.imread(r'contoh.jpg')
        im = mping.imread(r'contoh.jpg')
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img)
    else:
        print ("Pilihan kurang tepat silahkan ulangi lagi")
elif pilihan == 2:
    print ("Lanjutin")
else:
    print("pilihan anda salah")
# Out:
#           Selamat Datang
# ...
# Silahkan pilih menu yang diingginkan
# 1 = Untuk menampilkan gambar
# 2 = Untuk menampilkan Histogram
#
# Masukkan Pilihan Anda = 1
# Masukkan Pilihan Warna yang ingin Anda masukkan
# ...
# 1 untuk warna Gray
# 2 untuk warna RGB
#
# Masukkan Pilihan = 2
